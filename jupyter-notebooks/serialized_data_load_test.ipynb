# %%
import numpy as np

import utils.constants as consts
from utils.audio_tools import create_audio_player

path_to_mel_spec: str = '/datasets/serialized_dataset/flute/flute_G#_006449_stretched_segment_12.npy'
y: int = 1 + consts.SAMPLE_RATE // consts.MEL_HOP_LEN

mel_spectrogram: np.ndarray = np.load(path_to_mel_spec).reshape(-1, y)

# %%
create_audio_player(mel_spectrogram)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
