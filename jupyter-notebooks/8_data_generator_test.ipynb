# %%
import numpy as np

from ai_tools import DataGenerator
from ai_tools.displays import plot_history
from ai_tools.models import build_conv2d_example
from tensorflow.keras.models import Model
from typing import List
from utils.helpers import load_data, Data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_13325/1717092389.py in <module>
#       3 from ai_tools import DataGenerator
#       4 from ai_tools.displays import plot_history
# ----> 5 from ai_tools.models import build_conv2d_example
#       6 from tensorflow.keras.models import Model
#       7 from typing import List
#
# ~/dev/uni/auditory-deepdream/library/ai_tools/models.py in <module>
# ----> 1 from kapre.composed import get_melspectrogram_layer
#       2 from tensorflow.keras import Sequential, Model
#       3 from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, LayerNormalization, Dropout
#       4 from tensorflow.keras.losses import BinaryCrossentropy
#       5 from tensorflow.keras.activations import relu, sigmoid, softmax
#
# ~/anaconda3/envs/auditory-deep-dream/lib/python3.8/site-packages/kapre/__init__.py in <module>
#       2 VERSION = __version__
#       3
# ----> 4 from . import composed
#       5 from . import backend
#       6
#
# ~/anaconda3/envs/auditory-deep-dream/lib/python3.8/site-packages/kapre/composed.py in <module>
#      17 from tensorflow.keras import Sequential, Model
#      18
# ---> 19 from .time_frequency import (
#      20     STFT,
#      21     InverseSTFT,
#
# ~/anaconda3/envs/auditory-deep-dream/lib/python3.8/site-packages/kapre/time_frequency.py in <module>
#      23 from tensorflow.keras.layers import Layer
#      24
# ---> 25 from . import backend
#      26 from .backend import _CH_FIRST_STR, _CH_LAST_STR, _CH_DEFAULT_STR
#      27 from .tflite_compatible_stft import atan2_tflite
#
# ~/anaconda3/envs/auditory-deep-dream/lib/python3.8/site-packages/kapre/backend.py in <module>
#      12 import tensorflow as tf
#      13 import numpy as np
# ---> 14 import librosa
#      15
#      16 _CH_FIRST_STR = 'channels_first'
#
# ~/.local/lib/python3.8/site-packages/librosa/__init__.py in <module>
#     209 # And all the librosa sub-modules
#     210 from ._cache import cache
# --> 211 from . import core
#     212 from . import beat
#     213 from . import decompose
#
# ~/.local/lib/python3.8/site-packages/librosa/core/__init__.py in <module>
#       3 """ Core IO and DSP functions"""
#       4
# ----> 5 from .convert import *  # pylint: disable=wildcard-import
#       6 from .audio import *  # pylint: disable=wildcard-import
#       7 from .spectrum import *  # pylint: disable=wildcard-import
#
# ~/.local/lib/python3.8/site-packages/librosa/core/convert.py in <module>
#       5 import re
#       6 import numpy as np
# ----> 7 from . import notation
#       8 from ..util.exceptions import ParameterError
#       9
#
# ~/.local/lib/python3.8/site-packages/librosa/core/notation.py in <module>
#       6 import numpy as np
#       7 from .._cache import cache
# ----> 8 from ..util.exceptions import ParameterError
#       9
#      10 __all__ = [
#
# ~/.local/lib/python3.8/site-packages/librosa/util/__init__.py in <module>
#      81 """
#      82
# ---> 83 from .utils import *  # pylint: disable=wildcard-import
#      84 from .files import *  # pylint: disable=wildcard-import
#      85 from .matching import *  # pylint: disable=wildcard-import
#
# ~/.local/lib/python3.8/site-packages/librosa/util/utils.py in <module>
#       8
#       9 import numpy as np
# ---> 10 import numba
#      11 from numpy.lib.stride_tricks import as_strided
#      12
#
# ~/.local/lib/python3.8/site-packages/numba/__init__.py in <module>
#     196
#     197 _ensure_llvm()
# --> 198 _ensure_critical_deps()
#     199
#     200 # we know llvmlite is working as the above tests passed, import it now as SVML
#
# ~/.local/lib/python3.8/site-packages/numba/__init__.py in _ensure_critical_deps()
#     136         raise ImportError("Numba needs NumPy 1.17 or greater")
#     137     elif numpy_version > (1, 20):
# --> 138         raise ImportError("Numba needs NumPy 1.20 or less")
#     139
#     140     try:
#
# ImportError: Numba needs NumPy 1.20 or less

# %%
# Create train and validation generators.
train_data_generator, val_data_generator = DataGenerator.from_path_to_audio(
    '../data-sets/small_nsynth/train',
    batch_size=64
)

# Build model.
model: Model = build_conv2d_example()

# Train model.
history = model.fit(
    train_data_generator,
    validation_data=val_data_generator,
    epochs=3
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13325/2317436091.py in <module>
#       6
#       7 # Build model.
# ----> 8 model: Model = build_conv2d_example()
#       9
#      10 # Train model.
#
# NameError: name 'build_conv2d_example' is not defined

# %%
plot_history(history)

# %%
X_test: List[Data] = load_data('../data-sets/small_nsynth/test')

# model.evaluate(X_test, y_test)
