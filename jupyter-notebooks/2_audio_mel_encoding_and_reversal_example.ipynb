# %% [markdown]
# ### Audio encoding and reversal example
#
# In this notebook I used librosa to encode an audio file into a mel spectrogram, and then reverse it back into audio.

# %%
import librosa.display
from librosa.feature import melspectrogram
from librosa.feature.inverse import mel_to_audio
import numpy as np
from utils.displays import display_mel_spectrogram, display_audio_player
import utils.constants as consts

PATH_TO_AUDIO: str = '../audio-files'
PATH_TO_IMAGES: str = '../images'

# %% [markdown]
# ##### Load audio

# %%
sample, _ = librosa.load(f'{PATH_TO_AUDIO}/mandolin.wav', mono=True)  # type: np.ndarray, int
display_audio_player(sample)

# %% [markdown]
# ##### Encode audio into a mel spectrogram

# %%
encoded_sample: np.ndarray = melspectrogram(
    sample,
    sr=consts.SAMPLE_RATE,
    n_fft=consts.NUM_FFT,
    hop_length=consts.MEL_HOP_LEN,
    n_mels=consts.NUM_MELS
)

display_mel_spectrogram(encoded_sample)

# %% [markdown]
# ##### Convert mel spectrogram back into audio

# %%
reversed_sample: np.ndarray = mel_to_audio(
    encoded_sample,
    sr=consts.SAMPLE_RATE,
    n_iter=consts.MEL_TO_AUDIO_N_ITERATIONS

)

display_audio_player(reversed_sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b6b774324eee> in <module>
# ----> 1 reversed_sample: np.ndarray = mel_to_audio(
#       2     encoded_sample,
#       3     sr=consts.SAMPLE_RATE,
#       4     n_iter=consts.MEL_TO_AUDIO_N_ITERATIONS
#       5
#
# /usr/local/lib/python3.8/dist-packages/librosa/feature/inverse.py in mel_to_audio(M, sr, n_fft, hop_length, win_length, window, center, pad_mode, power, n_iter, length, dtype, **kwargs)
#     170     """
#     171
# --> 172     stft = mel_to_stft(M, sr=sr, n_fft=n_fft, power=power, **kwargs)
#     173
#     174     return griffinlim(
#
# /usr/local/lib/python3.8/dist-packages/librosa/feature/inverse.py in mel_to_stft(M, sr, n_fft, power, **kwargs)
#      86     # the inverse exponent.
#      87     # We'll do the exponentiation in-place.
# ---> 88     inverse = nnls(mel_basis, M)
#      89     return np.power(inverse, 1.0 / power, out=inverse)
#      90
#
# /usr/local/lib/python3.8/dist-packages/librosa/util/_nnls.py in nnls(A, B, **kwargs)
#     157     for bl_s in range(0, x.shape[-1], n_columns):
#     158         bl_t = min(bl_s + n_columns, B.shape[-1])
# --> 159         x[:, bl_s:bl_t] = _nnls_lbfgs_block(
#     160             A, B[:, bl_s:bl_t], x_init=x_init[:, bl_s:bl_t], **kwargs
#     161         )
#
# /usr/local/lib/python3.8/dist-packages/librosa/util/_nnls.py in _nnls_lbfgs_block(A, B, x_init, **kwargs)
#      75
#      76     # optimize
# ---> 77     x, obj_value, diagnostics = scipy.optimize.fmin_l_bfgs_b(
#      78         _nnls_obj, x_init, args=(shape, A, B), bounds=bounds, **kwargs
#      79     )
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     265         if not np.array_equal(x, self.x):
#     266             self._update_x_impl(x)
# --> 267         self._update_fun()
#     268         self._update_grad()
#     269         return self.f, self.g
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# /usr/local/lib/python3.8/dist-packages/librosa/util/_nnls.py in _nnls_obj(x, shape, A, B)
#      26
#      27     # Compute the difference matrix
# ---> 28     diff = np.dot(A, x) - B
#      29
#      30     # Compute the objective value
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
